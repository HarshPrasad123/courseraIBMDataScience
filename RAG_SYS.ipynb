# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshPrasad123/courseraIBMDataScience/blob/main/RAG_SYS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain

# %%
pip install openai

# %%
pip install psycopg2-binary

# %%
pip install pgvector

# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 7.0 MB/s eta 0:00:00
# ...

# %%
pip install beautifulsoup4

# %%
pip install requests

# %%
pip install nltk

# %%
import os

os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY_HERE"

# %%
import os

folders = [
    "data/raw_docs",
    "data/processed",
]

for f in folders:
    os.makedirs(f, exist_ok=True)

print("Folders ready")
# Out:
# Folders ready

# %%
import requests
import os

os.makedirs("data/raw_docs", exist_ok=True)

company_urls = {
   "Apple": "https://www.sec.gov/Archives/edgar/data/320193/000130817924000078/aapl2024_def14a.htm",
    "Microsoft": "https://www.sec.gov/Archives/edgar/data/789019/000119312524103056/d802194ddef14a.htm",
    "Amazon": "https://www.sec.gov/Archives/edgar/data/1018724/000119312524097225/d897711ddef14a.htm",
    "Google": "https://www.sec.gov/Archives/edgar/data/1652044/000119312524089042/d799294ddef14a.htm",
    "Meta": "https://www.sec.gov/Archives/edgar/data/1326801/000119312524090883/d807613ddef14a.htm",
    "Tesla": "https://www.sec.gov/Archives/edgar/data/1318605/000119312524094651/d812423ddef14a.htm",
    "Nvidia": "https://www.sec.gov/Archives/edgar/data/1045810/000119312524095862/d816910ddef14a.htm",
    "JPMorgan": "https://www.sec.gov/Archives/edgar/data/19617/000119312524088765/d781104ddef14a.htm",
    "Walmart": "https://www.sec.gov/Archives/edgar/data/104169/000119312524096771/d823456ddef14a.htm",
    "CocaCola": "https://www.sec.gov/Archives/edgar/data/21344/000120677424000312/ko_def14a.htm"

}

for company, url in company_urls.items():
    r = requests.get(url)   # ❌ no User-Agent
    with open(f"data/raw_docs/{company}.html", "wb") as f:
        f.write(r.content)
    print(f"{company} downloaded")



for company, url in company_urls.items():
    r = requests.get(url)   # ❌ no User-Agent
    with open(f"data/raw_docs/{company}.html", "wb") as f:
        f.write(r.content)
    print(f"{company} downloaded")
# Out:
# Apple downloaded
# Microsoft downloaded
# Amazon downloaded
# Google downloaded
# Meta downloaded
# Tesla downloaded
# Nvidia downloaded
# JPMorgan downloaded
# Walmart downloaded
# CocaCola downloaded
# Apple downloaded
# Microsoft downloaded
# Amazon downloaded
# Google downloaded
# Meta downloaded
# Tesla downloaded
# Nvidia downloaded
# JPMorgan downloaded
# Walmart downloaded
# CocaCola downloaded

# %%
from bs4 import BeautifulSoup
import os

os.makedirs("data/processed", exist_ok=True)

raw_dir = "data/raw_docs"
out_dir = "data/processed"

for file in os.listdir(raw_dir):
    if file.endswith(".html"):
        with open(os.path.join(raw_dir, file), "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f, "html.parser")
            text = soup.get_text(separator=" ")

        out_file = file.replace(".html", ".txt")
        with open(os.path.join(out_dir, out_file), "w", encoding="utf-8") as f:
            f.write(text)

        print(f"Extracted: {out_file}")
# Out:
# Extracted: JPMorgan.txt
# Extracted: Amazon.txt
# Extracted: Meta.txt
# Extracted: Tesla.txt
# Extracted: CocaCola.txt
# Extracted: Microsoft.txt
# Extracted: Apple.txt
# Extracted: Walmart.txt
# Extracted: Google.txt
# Extracted: Nvidia.txt

# %%
print(open("data/processed/Apple.txt", "r", encoding="utf-8").read()[:1000])
# Out:
#
#
#
#  SEC.gov | Your Request Originates from an Undeclared Automated Tool
#
#
#
#  U.S. Securities and Exchange Commission
#
#  Your Request Originates from an Undeclared Automated Tool
#  To allow for equitable access to all users, SEC reserves the right to limit requests originating from undeclared automated tools. Your request has been identified as part of a network of automated tools outside of the acceptable policy and will be managed until action is taken to declare your traffic.
#  Please declare your traffic by updating your user agent to include company specific information.
#  For best practices on efficiently downloading information from SEC.gov, including the latest EDGAR filings, visit  sec.gov/developer . You can also  sign up for email updates  on the SEC open data program, including best practices that make it more efficient to download data, and SEC.gov enhancements that may impact scripted downloading processes. For more information, contact  opendata@sec.gov .
# ...

# %%
import os, shutil

shutil.rmtree("data/raw_docs", ignore_errors=True)
shutil.rmtree("data/processed", ignore_errors=True)

os.makedirs("data/raw_docs", exist_ok=True)
os.makedirs("data/processed", exist_ok=True)

print("Old files deleted")
# Out:
# Old files deleted

# %%
import requests

headers = {
    "User-Agent": "Harsh Prasad (intern) harshpd1993@gmail.com"
}

url = "https://www.sec.gov/ixviewer/documents/2024/def14a/0001308179-24-000078/0001308179-24-000078.htm"
r = requests.get(url, headers=headers)

print("Status:", r.status_code)

with open("data/raw_docs/Apple.html", "wb") as f:
    f.write(r.content)
# Out:
# Status: 404

# %%
import requests, os

headers = {
    "User-Agent": "Harsh Prasad (intern) harshpd1993@gmail.com"
}

url = "https://investors.coca-colacompany.com/_assets/_b02778279da8d05e44b1e86f774ed908/cocacolacompany/db/892/10861/proxy_statement/0001558370-25-003056.pdf"
r = requests.get(url, headers=headers)

print("Status:", r.status_code)

with open("data/raw_docs/CocaCola.pdf", "wb") as f:
    f.write(r.content)
# Out:
# Status: 200

# %%
from pypdf import PdfReader

reader = PdfReader("data/raw_docs/CocaCola.pdf")

text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"

with open("data/processed/CocaCola.txt", "w", encoding="utf-8") as f:
    f.write(text)

print(text[:500])
# Out:
# UNITED STATESSECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
# SCHEDULE 14A
# Proxy Statement Pursuant to Section 14(a) ofthe Securities Exchange Act of 1934 (Amendment No.     )
# Filed by the Registrant  ☒
# Filed by a Party other than the Registrant  ☐
# Check the appropriate box:
# ☐ Preliminary Proxy Statement
# ☐ Confidential, for Use of the Commission Only (as permitted by Rule 14a-6(e)(2))
# ☒ Definitive Proxy Statement
# ☐ Definitive Additional Materials
# ☐ Soliciting Material under §240.14a-12
# _

# %%
import requests, os

headers = {
    "User-Agent": "Harsh Prasad (intern) harshpd1993@gmail.com"
}

os.makedirs("data/raw_docs", exist_ok=True)

company_pdfs = {
    "CocaCola": "https://investors.coca-colacompany.com/_assets/_b02778279da8d05e44b1e86f774ed908/cocacolacompany/db/892/10861/proxy_statement/0001558370-25-003056.pdf",
    "Microsoft": "https://www.microsoft.com/investor/reports/ar24/download/ProxyStatementFY24.pdf",
    "Amazon": "https://www.aboutamazon.com/annual-reports-proxy-statements-and-shareholder-letters",
    "Meta": "https://investor.fb.com/financials/sec-filings/default.aspx",
    "Alphabet": "https://abc.xyz/investor/other/sec-filings/",
    "Tesla": "https://ir.tesla.com/sec-filings",
    "Nvidia": "https://investor.nvidia.com/sec-filings/",
    "JPMorgan": "https://investor.shareholder.com/jpmorganchase/sec-filings.cfm",
    "Walmart": "https://stock.walmart.com/investors/financial-information/sec-filings/default.aspx"
}

for company, url in company_pdfs.items():
    r = requests.get(url, headers=headers)
    print(company, "status:", r.status_code)
    if r.status_code == 200:
        with open(f"data/raw_docs/{company}.pdf", "wb") as f:
            f.write(r.content)
# Out:
# CocaCola status: 200
# Microsoft status: 404
# Amazon status: 404
# Meta status: 403
# Alphabet status: 403
# Tesla status: 403
# Nvidia status: 403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-110198204.py in <cell line: 0>()
#      20
#      21 for company, url in company_pdfs.items():
# ---> 22     r = requests.get(url, headers=headers)
#      23     print(company, "status:", r.status_code)
#      24     if r.status_code == 200:
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ...

# %%
from bs4 import BeautifulSoup
import os

raw_dir = "data/raw_docs"
out_dir = "data/processed"
os.makedirs(out_dir, exist_ok=True)

for file in os.listdir(raw_dir):
    if file.endswith(".html"):
        with open(os.path.join(raw_dir, file), "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f, "html.parser")
            text = soup.get_text(" ")

        with open(os.path.join(out_dir, file.replace(".html", ".txt")), "w", encoding="utf-8") as f:
            f.write(text)

        print("Extracted:", file)
# Out:
# Extracted: Apple.html

# %%
from pypdf import PdfReader

reader = PdfReader("data/raw_docs/CocaCola.pdf")
text = ""
for page in reader.pages:
    if page.extract_text():
        text += page.extract_text() + "\n"

with open("data/processed/CocaCola.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("Extracted: CocaCola.pdf")
# Out:
# Extracted: CocaCola.pdf

# %%
def chunk_text(text, chunk_size=800, overlap=100):
    words = text.split()
    chunks = []
    i = 0
    while i < len(words):
        chunk = words[i:i+chunk_size]
        chunks.append(" ".join(chunk))
        i += chunk_size - overlap
    return chunks

import os

chunks_by_company = {}

for file in os.listdir("data/processed"):
    if file.endswith(".txt"):
        company = file.replace(".txt", "")
        text = open(f"data/processed/{file}", "r", encoding="utf-8").read()
        chunks_by_company[company] = chunk_text(text)
        print(company, "chunks:", len(chunks_by_company[company]))
# Out:
# Apple chunks: 1
# CocaCola chunks: 85

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-907070862.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-655143678.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
from bs4 import BeautifulSoup
import os

raw_dir = "data/raw_docs"
out_dir = "data/processed"
os.makedirs(out_dir, exist_ok=True)

for file in os.listdir(raw_dir):
    if file.endswith(".html"):
        with open(os.path.join(raw_dir, file), "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f, "html.parser")
            text = soup.get_text(" ")

        out_file = file.replace(".html", ".txt")
        with open(os.path.join(out_dir, out_file), "w", encoding="utf-8") as f:
            f.write(text)

        print("HTML extracted:", out_file)
# Out:
# HTML extracted: WALMART.txt
# HTML extracted: blackrock.txt
# HTML extracted: jpMorgan.txt
# HTML extracted: ALPHABET INC.txt
# HTML extracted: nvidia.txt
# HTML extracted: Apple.txt
# HTML extracted: keysight.txt
# HTML extracted: tesla.txt
# HTML extracted: GOOGLE INC.txt
# HTML extracted: meta.txt

# %%
from pypdf import PdfReader

reader = PdfReader("data/raw_docs/CocaCola.pdf")
text = ""

for page in reader.pages:
    if page.extract_text():
        text += page.extract_text() + "\n"

with open("data/processed/CocaCola.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("PDF extracted: CocaCola.txt")
# Out:
# PDF extracted: CocaCola.txt

# %%
def chunk_text(text, chunk_size=800, overlap=100):
    words = text.split()
    chunks = []
    i = 0
    while i < len(words):
        chunk = words[i:i+chunk_size]
        chunks.append(" ".join(chunk))
        i += chunk_size - overlap
    return chunks

# %%
import os

chunks_by_company = {}

for file in os.listdir("data/processed"):
    if file.endswith(".txt"):
        company = file.replace(".txt", "")
        with open(f"data/processed/{file}", "r", encoding="utf-8") as f:
            text = f.read()

        chunks = chunk_text(text)
        chunks_by_company[company] = chunks
        print(company, "chunks:", len(chunks))
# Out:
# WALMART chunks: 79
# Apple chunks: 1
# jpMorgan chunks: 73
# ALPHABET INC chunks: 80
# nvidia chunks: 38
# blackrock chunks: 110
# keysight chunks: 40
# tesla chunks: 39
# GOOGLE INC chunks: 51
# CocaCola chunks: 85
# meta chunks: 72

# %%
import os
os.remove("data/processed/Apple.txt")

# %%
from pypdf import PdfReader

reader = PdfReader("data/raw_docs/Apple.pdf")
text = ""

for page in reader.pages:
    if page.extract_text():
        text += page.extract_text() + "\n"

with open("data/processed/Apple.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("Apple PDF extracted")
# Out:
# WARNING:pypdf._reader:invalid pdf header: b'\n<!--'
# WARNING:pypdf._reader:EOF marker not found
# ---------------------------------------------------------------------------
# PdfStreamError                            Traceback (most recent call last)
# /tmp/ipython-input-3830263.py in <cell line: 0>()
#       1 from pypdf import PdfReader
#       2
# ----> 3 reader = PdfReader("data/raw_docs/Apple.pdf")
#       4 text = ""
#       5
#
# /usr/local/lib/python3.12/dist-packages/pypdf/_reader.py in __init__(self, stream, strict, password, root_object_recovery_limit)
#     142         self._validated_root: Optional[DictionaryObject] = None
#     143
# --> 144         self._initialize_stream(stream)
#     145         self._known_objects: set[tuple[int, int]] = set()
#     146
#
# /usr/local/lib/python3.12/dist-packages/pypdf/_reader.py in _initialize_stream(self, stream)
#     164                 stream = BytesIO(fh.read())
#     165             self._stream_opened = True
# ...

# %%
import os
os.remove("data/processed/Apple.txt")
print("Apple removed")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2505488658.py in <cell line: 0>()
#       1 import os
# ----> 2 os.remove("data/processed/Apple.txt")
#       3 print("Apple removed")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/Apple.txt'

# %%
pip install faiss-cpu sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 65.0 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("all-MiniLM-L6-v2")

texts = []
metadata = []

for company, chunks in chunks_by_company.items():
    for chunk in chunks:
        texts.append(chunk)
        metadata.append(company)

embeddings = model.encode(texts, show_progress_bar=True)
embeddings = np.array(embeddings).astype("float32")

print("Embeddings shape:", embeddings.shape)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
import faiss

dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(embeddings)

print("Total vectors stored:", index.ntotal)
# Out:
# Total vectors stored: 668

# %%
def search_keyword(query, top_k=10):
    q_emb = model.encode([query]).astype("float32")
    distances, indices = index.search(q_emb, top_k)

    results = {}
    for idx in indices[0]:
        company = metadata[idx]
        results[company] = results.get(company, 0) + 1

    return results

# %%
search_keyword("executive compensation")
# Out:
# {'WALMART': 1,
#  'keysight': 2,
#  'ALPHABET INC': 2,
#  'meta': 3,
#  'CocaCola': 1,
#  'tesla': 1}

# %%
# !zip -r DEF14A_RAG_data.zip data/
# Out:
#   adding: data/ (stored 0%)
#   adding: data/processed/ (stored 0%)
#   adding: data/processed/WALMART.txt (deflated 74%)
#   adding: data/processed/jpMorgan.txt (deflated 74%)
#   adding: data/processed/ALPHABET INC.txt (deflated 73%)
#   adding: data/processed/nvidia.txt (deflated 71%)
#   adding: data/processed/blackrock.txt (deflated 76%)
#   adding: data/processed/keysight.txt (deflated 74%)
#   adding: data/processed/tesla.txt (deflated 73%)
#   adding: data/processed/GOOGLE INC.txt (deflated 75%)
#   adding: data/processed/CocaCola.txt (deflated 72%)
#   adding: data/processed/meta.txt (deflated 72%)
#   adding: data/raw_docs/ (stored 0%)
#   adding: data/raw_docs/WALMART.html (deflated 90%)
#   adding: data/raw_docs/blackrock.html (deflated 91%)
#   adding: data/raw_docs/CocaCola.pdf (deflated 54%)
#   adding: data/raw_docs/jpMorgan.html (deflated 91%)
#   adding: data/raw_docs/ALPHABET INC.html (deflated 89%)
#   adding: data/raw_docs/nvidia.html (deflated 92%)
# ...
